# %% [markdown]
# <a href="https://colab.research.google.com/github/S4qk/Btp-Data-Science/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, wooooorld")
# Out:
# hello, wooooorld

# %%
print("estoy solo?")
# Out:
# estoy solo?

# %%
print("se ve esto?")
# Out:
# se ve esto?

# %% [markdown]
# ***Esta es una casilla de texto***

# %%
print("un punto")
# Out:
# un punto

# %%
print("estoy solo?")

# %% [markdown]
# ![8814ca6c0d4ff3430aa63acd9578c15c.jpg](data:image/jpeg;base64,...)

# %%
# Words in dictionary
words = set()

def check(word):
    print("Return true if word is in dictionary else false")
    return word.lower() in words

def load(dictionary):
    """Load dictionary into memory, returning true if successful else false"""
    try:
        with open(dictionary) as file:
            words.update(file.read().splitlines())
        return True
    except FileNotFoundError:
        return False

def size():
    """Returns number of words in dictionary if loaded else 0 if not yet loaded"""
    return len(words)

def unload():
    """Unloads dictionary from memory, returning true if successful else false"""
    words.clear()
    return True

# %%
import pandas as pandita
s=pandita.Series(['Matematicas', 'Historia', 'Ingles'], dtype='string')
print(s)
s.index
s.dtype
s.size
# Out:
# 0    Matematicas
# 1       Historia
# 2         Ingles
# dtype: string
# 3

# %%
zeta = " "
print(zeta)

# %%
lista = [1,2]
tupla = (3,4)
t2=(1,1)

tupla = tupla + t2
print(tupla)

res = lista + list(tupla)
print(res)

for x in lista + list(tupla):
  print(x)

print(lista + list(tupla))
# Out:
# (3, 4, 1, 1)
# [1, 2, 3, 4, 1, 1]
# 1
# 2
# 3
# 4
# 1
# 1
# [1, 2, 3, 4, 1, 1]

# %%
try:
    n = int(input("Input: "))
    print("Integer.")
except ValueError:
    print("Not integer.")


"""n = int(input("Input: "))

if n.isdigit():
    n = int(n)
    print("Integer.")
else:
    print("Not integer.")"""
# Out:
# Input: 25.2
# Not integer.
# 'n = int(input("Input: "))\n\nif n.isdigit():\n    n = int(n)\n    print("Integer.")\nelse:\n    print("Not integer.")'
